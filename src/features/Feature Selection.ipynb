# %% [markdown]
# # Load Packages

# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as ss
from collections import Counter
import math
from scipy import stats
# %matplotlib inline

# Feature Selection general package imports
from sklearn.feature_selection import SelectFromModel
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# We probably don't need gridlines, but if we do comment this line
sns.set(style='ticks')

flatui = ["#9b59b6", "#3498db", "#95a5a6", "#e74c3c", "#34495e", "#2ecc71"]
flatui = sns.color_palette(flatui)

# %% [markdown]
# # Set Up Parameters

# %%
# If you want to hard limit features selected, or if feature selection methods require a max:
num_feats = 50

# Classification or Regression Togggle
classification_toggle = 1

# %% [markdown]
# # Read Data and Preprocess

# %%
# Read dataframe

data = pd.read_csv("../../data/clean/model_plays.csv", low_memory = False)

# Test for run and pass predictors. Comment out if we don't want this
data = data[((data['target'] == 'run') |  (data['target'] == 'pass'))]

# Remove labels
del data['play_id']
del data['game_id']

# Separate Target from dataset
#firstdata['target'] = data['target'].astype('category')
#target_cat_label = dict(enumerate(data.target.categories))

# Change categorical variables to numerical
data['target'] = data['target'].astype('category').cat.codes
# data['target'] = data['target'].map(target_cat_label)

target = data['target']
del data['target']
y = target

# Normalize features
scaler = StandardScaler()
df = pd.DataFrame(scaler.fit_transform(data), columns = data.columns)

# Min Max features
min_scaler = MinMaxScaler()
df2 = pd.DataFrame(min_scaler.fit_transform(data), columns = data.columns)

feature_name = list(df.columns)

# %% [markdown]
# # Filter Methods
#
# Filter methods consider relationship between features and target variable
#
# # Pearson Correlation
#
# Pearson correlation usually works best with all numerical variables. Binary variables may (will) cause some issues, especially if there are more binary/categorical than numeric.

# %%
def cor_selector(X, y, num_feats):
    cor_list = []
    feature_name = X.columns.tolist()
    # calculate the correlation with y for each feature
    for i in X.columns.tolist():
        cor = np.corrcoef(X[i], y)[0,1]
        cor_list.append(cor)
    # Replace NaN with 0
    cor_list = [0 if np.isnan(i) else i for i in cor_list]
    # Feature name
    cor_feature = X.iloc[:, np.argsort(np.abs(cor_list))[-num_feats:]].columns.tolist()
    # Feature selection? 0 for not select, 1 for select
    cor_support = [True if i in cor_feature else False for i in feature_name]
    return cor_support, cor_feature
cor_support, cor_feature = cor_selector(df, y, num_feats)
print(str(len(cor_feature)), 'selected features')
# Out:
# 50 selected features
# C:\Users\halfc\anaconda3\lib\site-packages\numpy\lib\function_base.py:2534: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\halfc\anaconda3\lib\site-packages\numpy\lib\function_base.py:2535: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]

# %%
cor_feature
# Out:
# ['pd_avg_interceptions',
#  'ld_plays',
#  'ld_opp_outcome_fumble_lost',
#  'def_lolb',
#  'Dome',
#  'off_hb',
#  'pd_average_plays',
#  'ld_outcome_punt',
#  'off_qb',
#  'game_seconds_remaining',
#  'play_type_pass',
#  'air_yards',
#  'off_lt',
#  'ld_opp_outcome_interception',
#  'pd_pass_completion_pct',
#  'ld_opp_outcome_no_ld',
#  'qb_scramble',
#  'game_half',
#  'play_type_run',
#  'pd_average_sacks',
#  'ld_outcome_turnover_on_downs',
#  'ld_outcome_no_ld',
#  'off_wr',
#  'ld_opp_outcome_field_goal',
#  'play_type_qb_spike',
#  'qb_spike',
#  'pd_run_percentage',
#  'pd_average_points',
#  'ld_opp_outcome_touchdown',
#  'pd_passer_rating',
#  'ld_expl_run',
#  'down',
#  'play_end_total_ydstogo',
#  'ep',
#  'pd_expl_run',
#  'ld_start_yds_to_go',
#  'ld_opp_outcome_turnover_on_downs',
#  'ydsnet',
#  'sack',
#  'play_end_first_down_ydstogo',
#  'no_huddle',
#  'ydstogo',
#  'yards_after_catch',
#  'shotgun',
#  'def_team_pts_scored_vs_pace',
#  'pts_scored_vs_pace',
#  'adj_wp',
#  'score_differential',
#  'yards_gained',
#  'epa']

# %% [markdown]
# # Chi-Squared (Classification)
#
# Use calculated Chi-Squared to find feature set with the best scores. Only use for classification problems!

# %%
if classification_toggle == 1:
    from sklearn.feature_selection import SelectKBest, chi2
    
    chi_selector = SelectKBest(chi2, k = num_feats)
    chi_selector.fit(df2, y)
    chi_support = chi_selector.get_support()
    chi_feature = df.loc[:,chi_support].columns.tolist()
    print(str(len(chi_feature)), 'selected features')
else:
    None
# Out:
# 50 selected features

# %%
chi_feature
# Out:
# ['game_seconds_remaining',
#  'game_half',
#  'down',
#  'ydstogo',
#  'ydsnet',
#  'yards_gained',
#  'shotgun',
#  'no_huddle',
#  'qb_dropback',
#  'qb_spike',
#  'qb_scramble',
#  'score_differential',
#  'ep',
#  'epa',
#  'sack',
#  'fumble',
#  'Snow',
#  'Dome',
#  'off_lt',
#  'off_qb',
#  'pts_scored_vs_pace',
#  'def_team_pts_scored_vs_pace',
#  'adj_wp',
#  'play_end_first_down_ydstogo',
#  'play_end_total_ydstogo',
#  'ld_expl_run',
#  'ld_expl_pass',
#  'ld_start_yds_to_go',
#  'pd_expl_run',
#  'pd_average_points',
#  'pd_average_sacks',
#  'pd_avg_interceptions',
#  'pd_passer_rating',
#  'pd_run_percentage',
#  'pd_pass_completion_pct',
#  'play_type_pass',
#  'play_type_qb_spike',
#  'play_type_run',
#  'ld_outcome_fumble_lost',
#  'ld_outcome_interception',
#  'ld_outcome_no_ld',
#  'ld_outcome_punt',
#  'ld_outcome_touchdown',
#  'ld_outcome_turnover_on_downs',
#  'ld_opp_outcome_field_goal',
#  'ld_opp_outcome_fumble_lost',
#  'ld_opp_outcome_interception',
#  'ld_opp_outcome_no_ld',
#  'ld_opp_outcome_touchdown',
#  'ld_opp_outcome_turnover_on_downs']

# %% [markdown]
# # F-Test (Regression)
#
# Least Squares F-Test. Essentially, run a linear regression and test model and feature significance

# %%
from sklearn.feature_selection import f_regression, f_classif

if classification_toggle == 0:
    f_selector = SelectKBest(f_regression, k = num_feats)
    f_selector.fit(df,y)
    f_support = f_selector.get_support()
    f_feature = df.loc[:,f_support].columns.tolist()
    print(str(len(f_feature)), 'selected features')
else:
    X_indices = np.arange(df.shape[-1])
    f_selector = SelectKBest(f_classif, k = num_feats)
    f_selector.fit(df, y)
    f_support = f_selector.get_support()
    f_feature = df.loc[:,f_support].columns.tolist()
    print(str(len(f_feature)), 'selected features')
# Out:
# 50 selected features
# C:\Users\halfc\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:115: UserWarning: Features [70] are constant.
#   UserWarning)
# C:\Users\halfc\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw

# %%
f_feature
# Out:
# ['game_seconds_remaining',
#  'game_half',
#  'down',
#  'ydstogo',
#  'ydsnet',
#  'yards_gained',
#  'shotgun',
#  'no_huddle',
#  'qb_spike',
#  'qb_scramble',
#  'air_yards',
#  'yards_after_catch',
#  'score_differential',
#  'ep',
#  'epa',
#  'sack',
#  'Dome',
#  'off_hb',
#  'off_lt',
#  'off_qb',
#  'off_wr',
#  'def_lolb',
#  'pts_scored_vs_pace',
#  'def_team_pts_scored_vs_pace',
#  'adj_wp',
#  'play_end_first_down_ydstogo',
#  'play_end_total_ydstogo',
#  'ld_plays',
#  'ld_expl_run',
#  'ld_start_yds_to_go',
#  'pd_expl_run',
#  'pd_average_points',
#  'pd_average_plays',
#  'pd_average_sacks',
#  'pd_avg_interceptions',
#  'pd_passer_rating',
#  'pd_run_percentage',
#  'pd_pass_completion_pct',
#  'play_type_pass',
#  'play_type_qb_spike',
#  'play_type_run',
#  'ld_outcome_no_ld',
#  'ld_outcome_punt',
#  'ld_outcome_turnover_on_downs',
#  'ld_opp_outcome_field_goal',
#  'ld_opp_outcome_fumble_lost',
#  'ld_opp_outcome_interception',
#  'ld_opp_outcome_no_ld',
#  'ld_opp_outcome_touchdown',
#  'ld_opp_outcome_turnover_on_downs']

# %% [markdown]
# # Mutual Information
#
# Measures the dependence of one variable to another. Has relative advantage over F-Test because it can contend with non-linear relationships

# %%
from sklearn.feature_selection import mutual_info_regression, mutual_info_classif

if classification_toggle == 0:
    mutual_selector = SelectKBest(mutual_info_regression, k = num_feats)
    mutual_selector.fit(df, y)
    mutual_support = mutual_selector.get_support()
    mutual_feature = df.loc[:, mutual_support].columns.tolist()
    print(str(len(mutual_feature)), 'selected features')
else:
    mutual_selector = SelectKBest(mutual_info_classif, k = num_feats)
    mutual_selector.fit(df, y)
    mutual_support = mutual_selector.get_support()
    mutual_feature = df.loc[:, mutual_support].columns.tolist()
    print(str(len(mutual_feature)), 'selected features')
# Out:
# 50 selected features

# %%
mutual_feature
# Out:
# ['game_seconds_remaining',
#  'game_half',
#  'qtr',
#  'down',
#  'ydstogo',
#  'ydsnet',
#  'yards_gained',
#  'shotgun',
#  'no_huddle',
#  'qb_dropback',
#  'yards_after_catch',
#  'score_differential',
#  'ep',
#  'epa',
#  'sack',
#  'Rain',
#  'Wind',
#  'Dome',
#  'GameMonth',
#  'pts_scored_vs_pace',
#  'def_team_pts_scored_vs_pace',
#  'adj_wp',
#  'ld_expl_run',
#  'ld_expl_pass',
#  'pd_expl_run',
#  'pd_average_points',
#  'pd_average_top',
#  'pd_average_sacks',
#  'pd_average_tfl',
#  'pd_avg_interceptions',
#  'pd_passer_rating',
#  'pd_run_percentage',
#  'pd_pass_yard_att',
#  'pd_rush_yard_att',
#  'home',
#  'play_type_pass',
#  'play_type_run',
#  'ld_outcome_field_goal',
#  'ld_outcome_fumble_lost',
#  'ld_outcome_interception',
#  'ld_outcome_no_ld',
#  'ld_outcome_punt',
#  'ld_outcome_touchdown',
#  'ld_opp_outcome_end_of_half',
#  'ld_opp_outcome_field_goal',
#  'ld_opp_outcome_fumble_lost',
#  'ld_opp_outcome_no_ld',
#  'ld_opp_outcome_punt',
#  'ld_opp_outcome_touchdown',
#  'ld_opp_outcome_turnover_on_downs']

# %% [markdown]
# # Variance Threshold
#
# Variance threshold identifies features with variations below a certain cutoff point. The intuition is - if a feature doesn't vary too much, we assume it doesn't have a lot of predictive power.
#
# NOTE: This metric does not consider relationship of the feature and the target variable

# %%
from sklearn.feature_selection import VarianceThreshold
selector = VarianceThreshold()
selector.fit(df)

variance_selectors = selector.get_support()
variance_selectors
variance_features = list(df.columns[np.array(variance_selectors).astype(bool)])
variance_features
# Out:
# ['yardline_100',
#  'game_seconds_remaining',
#  'game_half',
#  'qtr',
#  'down',
#  'ydstogo',
#  'ydsnet',
#  'yards_gained',
#  'shotgun',
#  'no_huddle',
#  'qb_dropback',
#  'qb_spike',
#  'qb_scramble',
#  'air_yards',
#  'yards_after_catch',
#  'score_differential',
#  'ep',
#  'epa',
#  'sack',
#  'fumble',
#  'Rain',
#  'Snow',
#  'Wind',
#  'Fog',
#  'Dome',
#  'GameMonth',
#  'off_c',
#  'off_hb',
#  'off_lg',
#  'off_lt',
#  'off_qb',
#  'off_rg',
#  'off_rt',
#  'off_te',
#  'off_wr',
#  'def_cb',
#  'def_dt',
#  'def_fs',
#  'def_le',
#  'def_lolb',
#  'def_mlb',
#  'def_re',
#  'def_rolb',
#  'def_ss',
#  'pts_scored_vs_pace',
#  'def_team_pts_scored_vs_pace',
#  'adj_wp',
#  'play_end_first_down_ydstogo',
#  'play_end_total_ydstogo',
#  'ld_plays',
#  'ld_drive_length',
#  'ld_expl_run',
#  'ld_expl_pass',
#  'ld_start_yds_to_go',
#  'pd_expl_pass',
#  'pd_expl_run',
#  'pd_average_points',
#  'pd_average_plays',
#  'pd_average_top',
#  'pd_average_sacks',
#  'pd_average_tfl',
#  'pd_avg_interceptions',
#  'pd_passer_rating',
#  'pd_run_percentage',
#  'pd_pass_yard_att',
#  'pd_rush_yard_att',
#  'pd_pass_completion_pct',
#  'home',
#  'play_type_field_goal',
#  'play_type_pass',
#  'play_type_qb_kneel',
#  'play_type_qb_spike',
#  'play_type_run',
#  'ld_outcome_end_of_half',
#  'ld_outcome_field_goal',
#  'ld_outcome_fumble_lost',
#  'ld_outcome_interception',
#  'ld_outcome_no_ld',
#  'ld_outcome_punt',
#  'ld_outcome_touchdown',
#  'ld_outcome_turnover_on_downs',
#  'ld_opp_outcome_end_of_half',
#  'ld_opp_outcome_field_goal',
#  'ld_opp_outcome_fumble_lost',
#  'ld_opp_outcome_interception',
#  'ld_opp_outcome_no_ld',
#  'ld_opp_outcome_punt',
#  'ld_opp_outcome_touchdown',
#  'ld_opp_outcome_turnover_on_downs']

# %%
print(len(variance_features))
# Out:
# 89

# %%
tups = []

for c in enumerate(df.columns):
    tups.append((c[1], selector.variances_[c[0]]))
    
tups
# Out:
# [('yardline_100', 0.9999999999999997),
#  ('game_seconds_remaining', 1.0000000000000002),
#  ('game_half', 1.0000000000000007),
#  ('qtr', 0.9999999999999997),
#  ('down', 0.9999999999999992),
#  ('ydstogo', 1.0000000000000002),
#  ('ydsnet', 1.0),
#  ('yards_gained', 0.9999999999999999),
#  ('shotgun', 1.0),
#  ('no_huddle', 0.9999999999999999),
#  ('qb_dropback', 1.0000000000000007),
#  ('qb_spike', 1.000000000000001),
#  ('qb_scramble', 1.0),
#  ('air_yards', 1.0),
#  ('yards_after_catch', 1.0000000000000002),
#  ('score_differential', 1.0),
#  ('ep', 1.0),
#  ('epa', 1.0),
#  ('sack', 1.0000000000000002),
#  ('fumble', 1.0000000000000007),
#  ('Rain', 1.0),
#  ('Snow', 1.0000000000000002),
#  ('Wind', 0.9999999999999999),
#  ('Fog', 1.0000000000000007),
#  ('Dome', 0.9999999999999997),
#  ('GameMonth', 1.0),
#  ('off_c', 1.0000000000000002),
#  ('off_hb', 0.9999999999999996),
#  ('off_lg', 1.0),
#  ('off_lt', 1.0000000000000002),
#  ('off_qb', 1.0),
#  ('off_rg', 1.0000000000000002),
#  ('off_rt', 1.0),
#  ('off_te', 1.0000000000000002),
#  ('off_wr', 0.9999999999999999),
#  ('def_cb', 1.0000000000000002),
#  ('def_dt', 0.9999999999999999),
#  ('def_fs', 1.0000000000000002),
#  ('def_le', 0.9999999999999999),
#  ('def_lolb', 1.0000000000000002),
#  ('def_mlb', 0.9999999999999997),
#  ('def_re', 1.0000000000000002),
#  ('def_rolb', 0.9999999999999997),
#  ('def_ss', 0.9999999999999999),
#  ('pts_scored_vs_pace', 1.0000000000000002),
#  ('def_team_pts_scored_vs_pace', 0.9999999999999997),
#  ('adj_wp', 1.0000000000000002),
#  ('play_end_first_down_ydstogo', 1.0),
#  ('play_end_total_ydstogo', 0.9999999999999999),
#  ('ld_plays', 0.9999999999999997),
#  ('ld_drive_length', 1.0),
#  ('ld_expl_run', 0.9999999999999999),
#  ('ld_expl_pass', 1.0000000000000002),
#  ('ld_start_yds_to_go', 0.9999999999999996),
#  ('pd_expl_pass', 1.0000000000000002),
#  ('pd_expl_run', 1.0000000000000004),
#  ('pd_average_points', 1.0000000000000002),
#  ('pd_average_plays', 1.0),
#  ('pd_average_top', 1.0000000000000002),
#  ('pd_average_sacks', 0.9999999999999997),
#  ('pd_average_tfl', 1.0),
#  ('pd_avg_interceptions', 0.9999999999999996),
#  ('pd_passer_rating', 0.9999999999999999),
#  ('pd_run_percentage', 1.0000000000000002),
#  ('pd_pass_yard_att', 0.9999999999999997),
#  ('pd_rush_yard_att', 0.9999999999999999),
#  ('pd_pass_completion_pct', 1.0000000000000002),
#  ('home', 1.0),
#  ('play_type_field_goal', 1.0000000000000013),
#  ('play_type_pass', 0.9999999999999997),
#  ('play_type_punt', 0.0),
#  ('play_type_qb_kneel', 0.9999999999999987),
#  ('play_type_qb_spike', 1.000000000000001),
#  ('play_type_run', 1.0),
#  ('ld_outcome_end_of_half', 0.9999999999999997),
#  ('ld_outcome_field_goal', 0.9999999999999997),
#  ('ld_outcome_fumble_lost', 1.0),
#  ('ld_outcome_interception', 0.9999999999999996),
#  ('ld_outcome_no_ld', 0.9999999999999999),
#  ('ld_outcome_punt', 1.0000000000000004),
#  ('ld_outcome_touchdown', 0.9999999999999999),
#  ('ld_outcome_turnover_on_downs', 0.9999999999999997),
#  ('ld_opp_outcome_end_of_half', 1.0),
#  ('ld_opp_outcome_field_goal', 0.9999999999999999),
#  ('ld_opp_outcome_fumble_lost', 1.0000000000000002),
#  ('ld_opp_outcome_interception', 1.0),
#  ('ld_opp_outcome_no_ld', 1.0000000000000002),
#  ('ld_opp_outcome_punt', 1.0),
#  ('ld_opp_outcome_touchdown', 1.0),
#  ('ld_opp_outcome_turnover_on_downs', 1.0000000000000002)]

# %% [markdown]
# # Recursive Feature Elimination
#
# Eliminates worst performing features one after another until a best subset is known

# %%
from sklearn.feature_selection import RFE
from sklearn.ensemble import GradientBoostingClassifier

clf=GradientBoostingClassifier(n_estimators = 800, 
                               loss = 'exponential', 
                               learning_rate = 0.01, 
                               max_depth = 7, 
                               min_samples_split = 50, 
                               min_samples_leaf = 64,
                               max_features = 'auto')
rfe_selector = RFE(estimator = clf, n_features_to_select = num_feats, step = 10, verbose = 5)
rfe_selector.fit(df, y)
# Out:
# Fitting estimator with 90 features.
# Fitting estimator with 80 features.
# Fitting estimator with 70 features.
# Fitting estimator with 60 features.
# RFE(estimator=GradientBoostingClassifier(learning_rate=0.01, loss='exponential',
#                                          max_depth=7, max_features='auto',
#                                          min_samples_leaf=64,
#                                          min_samples_split=50,
#                                          n_estimators=800),
#     n_features_to_select=50, step=10, verbose=5)

# %%
rfe_support = rfe_selector.get_support()
rfe_feature = df.loc[:,rfe_support].columns.tolist()
print(str(len(rfe_feature)), 'selected features')
# Out:
# 50 selected features

# %%
rfe_feature
# Out:
# ['yardline_100',
#  'game_seconds_remaining',
#  'game_half',
#  'qtr',
#  'down',
#  'ydstogo',
#  'ydsnet',
#  'yards_gained',
#  'shotgun',
#  'no_huddle',
#  'qb_dropback',
#  'air_yards',
#  'score_differential',
#  'ep',
#  'epa',
#  'off_c',
#  'off_hb',
#  'off_lg',
#  'off_lt',
#  'off_qb',
#  'off_rg',
#  'off_rt',
#  'off_te',
#  'off_wr',
#  'def_cb',
#  'def_dt',
#  'def_fs',
#  'def_le',
#  'def_lolb',
#  'def_mlb',
#  'def_re',
#  'def_rolb',
#  'def_ss',
#  'pts_scored_vs_pace',
#  'def_team_pts_scored_vs_pace',
#  'adj_wp',
#  'play_end_first_down_ydstogo',
#  'play_end_total_ydstogo',
#  'ld_drive_length',
#  'ld_start_yds_to_go',
#  'pd_expl_run',
#  'pd_average_points',
#  'pd_average_plays',
#  'pd_average_top',
#  'pd_passer_rating',
#  'pd_run_percentage',
#  'pd_pass_yard_att',
#  'pd_rush_yard_att',
#  'pd_pass_completion_pct',
#  'play_type_run']

# %% [markdown]
# # Sequential Feature Selector

# %%
from sklearn.neighbors import KNeighborsClassifier
from mlxtend.feature_selection import SequentialFeatureSelector as SFS

knn = KNeighborsClassifier(n_neighbors=3)

# Selection Forward Selection
sfs1 = SFS(knn, 
           k_features= num_feats, 
           forward=True, 
           floating=False, 
           verbose=2,
           scoring='accuracy',
           cv=0)

sfs1 = sfs1.fit(df, y)

sfs1.k_feature_idx_
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    7.4s remaining:    0.0s

# %%
sfs1.k_feature_names_

# %%
sfs1.k_score_

# %% [markdown]
# # Embedded Methods
#
# ## Lasso Regression
#
# Put an L1 penalty to squeeze out unimportant features

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LassoCV

embedded_lr_selector = SelectFromModel(LassoCV(), max_features = num_feats)
embedded_lr_selector.fit(df, y)
# Out:
# SelectFromModel(estimator=LassoCV(), max_features=50)

# %%
embedded_lr_support = embedded_lr_selector.get_support()
embedded_lr_feature = df.loc[:, embedded_lr_support].columns.tolist()
print(str(len(embedded_lr_feature)), 'selected features')
# Out:
# 50 selected features

# %%
embedded_lr_feature
# Out:
# ['yardline_100',
#  'game_seconds_remaining',
#  'game_half',
#  'qtr',
#  'down',
#  'ydstogo',
#  'yards_gained',
#  'shotgun',
#  'no_huddle',
#  'qb_dropback',
#  'qb_spike',
#  'air_yards',
#  'yards_after_catch',
#  'score_differential',
#  'ep',
#  'epa',
#  'sack',
#  'fumble',
#  'Rain',
#  'Snow',
#  'Dome',
#  'off_c',
#  'off_lt',
#  'off_qb',
#  'off_rt',
#  'off_wr',
#  'def_cb',
#  'def_dt',
#  'def_mlb',
#  'pts_scored_vs_pace',
#  'adj_wp',
#  'play_end_total_ydstogo',
#  'ld_plays',
#  'ld_drive_length',
#  'ld_expl_run',
#  'ld_expl_pass',
#  'ld_start_yds_to_go',
#  'pd_expl_run',
#  'pd_average_points',
#  'pd_average_top',
#  'pd_passer_rating',
#  'pd_run_percentage',
#  'pd_pass_completion_pct',
#  'home',
#  'play_type_qb_spike',
#  'ld_outcome_turnover_on_downs',
#  'ld_opp_outcome_fumble_lost',
#  'ld_opp_outcome_interception',
#  'ld_opp_outcome_touchdown',
#  'ld_opp_outcome_turnover_on_downs']

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

embedded_clf_selector = SelectFromModel(RandomForestClassifier(n_estimators = 100))
embedded_clf_selector.fit(df, y)

embedded_clf_support = embedded_clf_selector.get_support()
embedded_clf_feature = df.loc[:, embedded_clf_support].columns.tolist()
print(str(len(embedded_clf_feature)), 'selected features')
# Out:
# 42 selected features

# %%
embedded_clf_feature
# Out:
# ['yardline_100',
#  'game_seconds_remaining',
#  'down',
#  'ydstogo',
#  'ydsnet',
#  'yards_gained',
#  'air_yards',
#  'score_differential',
#  'ep',
#  'epa',
#  'off_c',
#  'off_hb',
#  'off_lg',
#  'off_lt',
#  'off_qb',
#  'off_rg',
#  'off_rt',
#  'off_te',
#  'off_wr',
#  'def_cb',
#  'def_dt',
#  'def_fs',
#  'def_le',
#  'def_lolb',
#  'def_mlb',
#  'def_re',
#  'def_rolb',
#  'def_ss',
#  'pts_scored_vs_pace',
#  'def_team_pts_scored_vs_pace',
#  'adj_wp',
#  'play_end_first_down_ydstogo',
#  'play_end_total_ydstogo',
#  'ld_drive_length',
#  'ld_start_yds_to_go',
#  'pd_average_plays',
#  'pd_average_top',
#  'pd_passer_rating',
#  'pd_run_percentage',
#  'pd_pass_yard_att',
#  'pd_rush_yard_att',
#  'pd_pass_completion_pct']

# %% [markdown]
# ## LightGBM

# %%
from lightgbm.sklearn import LGBMClassifier

# %%
lgbc = LGBMClassifier()

embedded_lgb_selector = SelectFromModel(lgbc, max_features = num_feats)
embedded_lgb_selector.fit(df,y)

embedded_lgb_support = embedded_lgb_selector.get_support()
embedded_lgb_feature = df.loc[:,  embedded_lgb_support].columns.tolist()
print(str(len(embedded_lgb_feature)), 'selected features')
# Out:
# 23 selected features

# %%
embedded_lgb_feature
# Out:
# ['yardline_100',
#  'game_seconds_remaining',
#  'down',
#  'ydstogo',
#  'ydsnet',
#  'yards_gained',
#  'shotgun',
#  'qb_dropback',
#  'score_differential',
#  'ep',
#  'epa',
#  'off_c',
#  'off_lt',
#  'off_qb',
#  'off_wr',
#  'pts_scored_vs_pace',
#  'def_team_pts_scored_vs_pace',
#  'adj_wp',
#  'play_end_first_down_ydstogo',
#  'play_end_total_ydstogo',
#  'pd_passer_rating',
#  'pd_run_percentage',
#  'pd_rush_yard_att']

# %% [markdown]
# # CatBoost

# %%
from catboost import CatBoostClassifier

cbr = CatBoostClassifier()

embedded_cbr_selector = SelectFromModel(cbr)
embedded_cbr_selector.fit(df, y)

embedded_cbr_support = embedded_cbr_selector.get_support()
embedded_cbr_feature = df.loc[:,  embedded_cbr_support].columns.tolist()
print(str(len(embedded_cbr_feature)), 'selected features')
# Out:
# Learning rate set to 0.097862
# 0:	learn: 0.6773633	total: 201ms	remaining: 3m 20s
# 1:	learn: 0.6650804	total: 235ms	remaining: 1m 57s
# 2:	learn: 0.6544021	total: 267ms	remaining: 1m 28s
# 3:	learn: 0.6455472	total: 300ms	remaining: 1m 14s
# 4:	learn: 0.6382975	total: 333ms	remaining: 1m 6s
# 5:	learn: 0.6326226	total: 362ms	remaining: 60s
# 6:	learn: 0.6277659	total: 390ms	remaining: 55.3s
# 7:	learn: 0.6231966	total: 421ms	remaining: 52.2s
# 8:	learn: 0.6194382	total: 452ms	remaining: 49.8s
# 9:	learn: 0.6161917	total: 478ms	remaining: 47.3s
# 10:	learn: 0.6135855	total: 505ms	remaining: 45.4s
# 11:	learn: 0.6112632	total: 535ms	remaining: 44s
# 12:	learn: 0.6077778	total: 561ms	remaining: 42.6s
# 13:	learn: 0.6055598	total: 589ms	remaining: 41.5s
# 14:	learn: 0.6037437	total: 618ms	remaining: 40.6s
# 15:	learn: 0.6022806	total: 647ms	remaining: 39.8s
# 16:	learn: 0.6008801	total: 676ms	remaining: 39.1s
# 17:	learn: 0.5990918	total: 704ms	remaining: 38.4s
# 18:	learn: 0.5980844	total: 729ms	remaining: 37.6s
# 19:	learn: 0.5969747	total: 757ms	remaining: 37.1s
# 20:	learn: 0.5953778	total: 787ms	remaining: 36.7s
# 347:	learn: 0.5496234	total: 11.3s	remaining: 21.1s
# 348:	learn: 0.5495395	total: 11.3s	remaining: 21.1s
# 349:	learn: 0.5494830	total: 11.3s	remaining: 21.1s
# 350:	learn: 0.5494409	total: 11.4s	remaining: 21s
# 351:	learn: 0.5494290	total: 11.4s	remaining: 21s
# 352:	learn: 0.5493763	total: 11.4s	remaining: 20.9s
# 353:	learn: 0.5493101	total: 11.5s	remaining: 20.9s
# 354:	learn: 0.5492402	total: 11.5s	remaining: 20.9s
# 355:	learn: 0.5491805	total: 11.5s	remaining: 20.9s
# 356:	learn: 0.5491231	total: 11.6s	remaining: 20.8s
# 357:	learn: 0.5490671	total: 11.6s	remaining: 20.8s
# 358:	learn: 0.5490012	total: 11.6s	remaining: 20.7s
# 359:	learn: 0.5489481	total: 11.6s	remaining: 20.7s
# 360:	learn: 0.5489069	total: 11.7s	remaining: 20.7s
# 361:	learn: 0.5488219	total: 11.7s	remaining: 20.6s
# 362:	learn: 0.5487709	total: 11.7s	remaining: 20.6s
# 363:	learn: 0.5487142	total: 11.8s	remaining: 20.6s
# 364:	learn: 0.5486404	total: 11.8s	remaining: 20.5s
# 365:	learn: 0.5485657	total: 11.8s	remaining: 20.5s
# 366:	learn: 0.5485014	total: 11.9s	remaining: 20.5s
# 367:	learn: 0.5484293	total: 11.9s	remaining: 20.4s
# 368:	learn: 0.5483893	total: 11.9s	remaining: 20.4s
# 369:	learn: 0.5483255	total: 12s	remaining: 20.4s
# 370:	learn: 0.5482883	total: 12s	remaining: 20.3s
# 371:	learn: 0.5482251	total: 12s	remaining: 20.3s
# 372:	learn: 0.5481576	total: 12.1s	remaining: 20.3s
# 373:	learn: 0.5480776	total: 12.1s	remaining: 20.3s
# 374:	learn: 0.5480322	total: 12.2s	remaining: 20.3s
# 375:	learn: 0.5480131	total: 12.2s	remaining: 20.2s
# 376:	learn: 0.5479526	total: 12.2s	remaining: 20.2s
# 377:	learn: 0.5478930	total: 12.3s	remaining: 20.2s
# 378:	learn: 0.5478320	total: 12.3s	remaining: 20.1s
# 379:	learn: 0.5477795	total: 12.3s	remaining: 20.1s
# 380:	learn: 0.5477240	total: 12.4s	remaining: 20.1s
# 381:	learn: 0.5476719	total: 12.4s	remaining: 20s
# 382:	learn: 0.5476151	total: 12.4s	remaining: 20s
# 383:	learn: 0.5475478	total: 12.4s	remaining: 20s
# 384:	learn: 0.5474906	total: 12.5s	remaining: 19.9s
# 385:	learn: 0.5474398	total: 12.5s	remaining: 19.9s
# 386:	learn: 0.5473770	total: 12.5s	remaining: 19.9s
# 387:	learn: 0.5473185	total: 12.6s	remaining: 19.8s
# 388:	learn: 0.5472161	total: 12.6s	remaining: 19.8s
# 389:	learn: 0.5471684	total: 12.6s	remaining: 19.7s
# 390:	learn: 0.5470878	total: 12.7s	remaining: 19.7s
# 391:	learn: 0.5470305	total: 12.7s	remaining: 19.7s
# 392:	learn: 0.5469781	total: 12.7s	remaining: 19.7s
# 393:	learn: 0.5469277	total: 12.8s	remaining: 19.6s
# 487:	learn: 0.5418696	total: 15.7s	remaining: 16.5s
# 488:	learn: 0.5418283	total: 15.7s	remaining: 16.4s
# 489:	learn: 0.5418174	total: 15.7s	remaining: 16.4s
# 490:	learn: 0.5417700	total: 15.8s	remaining: 16.4s
# 491:	learn: 0.5417151	total: 15.8s	remaining: 16.3s
# 492:	learn: 0.5416746	total: 15.8s	remaining: 16.3s
# 493:	learn: 0.5416233	total: 15.9s	remaining: 16.3s
# 494:	learn: 0.5415673	total: 15.9s	remaining: 16.2s
# 495:	learn: 0.5415050	total: 15.9s	remaining: 16.2s
# 496:	learn: 0.5414642	total: 16s	remaining: 16.2s
# 497:	learn: 0.5414229	total: 16s	remaining: 16.1s
# 498:	learn: 0.5413693	total: 16s	remaining: 16.1s
# 499:	learn: 0.5413238	total: 16.1s	remaining: 16.1s
# 500:	learn: 0.5412802	total: 16.1s	remaining: 16s
# 501:	learn: 0.5412212	total: 16.1s	remaining: 16s
# 502:	learn: 0.5411611	total: 16.2s	remaining: 16s
# 503:	learn: 0.5410753	total: 16.2s	remaining: 15.9s
# 504:	learn: 0.5410340	total: 16.2s	remaining: 15.9s
# 505:	learn: 0.5409921	total: 16.2s	remaining: 15.9s
# 506:	learn: 0.5409328	total: 16.3s	remaining: 15.8s
# 507:	learn: 0.5408693	total: 16.3s	remaining: 15.8s
# 508:	learn: 0.5408150	total: 16.3s	remaining: 15.8s
# 509:	learn: 0.5407808	total: 16.4s	remaining: 15.7s
# 510:	learn: 0.5407178	total: 16.4s	remaining: 15.7s
# 511:	learn: 0.5406782	total: 16.4s	remaining: 15.7s
# 512:	learn: 0.5406256	total: 16.5s	remaining: 15.6s
# 513:	learn: 0.5405775	total: 16.5s	remaining: 15.6s
# 514:	learn: 0.5405240	total: 16.5s	remaining: 15.6s
# 515:	learn: 0.5404831	total: 16.5s	remaining: 15.5s
# 516:	learn: 0.5404126	total: 16.6s	remaining: 15.5s
# 517:	learn: 0.5403572	total: 16.6s	remaining: 15.5s
# 518:	learn: 0.5403084	total: 16.6s	remaining: 15.4s
# 519:	learn: 0.5402669	total: 16.7s	remaining: 15.4s
# 520:	learn: 0.5402279	total: 16.7s	remaining: 15.3s
# 521:	learn: 0.5401796	total: 16.7s	remaining: 15.3s
# 522:	learn: 0.5401359	total: 16.8s	remaining: 15.3s
# 523:	learn: 0.5400672	total: 16.8s	remaining: 15.3s
# 524:	learn: 0.5400266	total: 16.8s	remaining: 15.2s
# 525:	learn: 0.5399707	total: 16.9s	remaining: 15.2s
# 526:	learn: 0.5399134	total: 16.9s	remaining: 15.2s
# 527:	learn: 0.5398634	total: 16.9s	remaining: 15.1s
# 528:	learn: 0.5398102	total: 17s	remaining: 15.1s
# 529:	learn: 0.5397522	total: 17s	remaining: 15.1s
# 530:	learn: 0.5396875	total: 17s	remaining: 15s
# 531:	learn: 0.5396487	total: 17.1s	remaining: 15s
# 532:	learn: 0.5395885	total: 17.1s	remaining: 15s
# 533:	learn: 0.5395458	total: 17.1s	remaining: 15s
# 628:	learn: 0.5348289	total: 20.2s	remaining: 11.9s
# 629:	learn: 0.5347850	total: 20.2s	remaining: 11.9s
# 630:	learn: 0.5347502	total: 20.2s	remaining: 11.8s
# 631:	learn: 0.5346991	total: 20.3s	remaining: 11.8s
# 632:	learn: 0.5346421	total: 20.3s	remaining: 11.8s
# 633:	learn: 0.5345796	total: 20.3s	remaining: 11.7s
# 634:	learn: 0.5345402	total: 20.4s	remaining: 11.7s
# 635:	learn: 0.5345001	total: 20.4s	remaining: 11.7s
# 636:	learn: 0.5344719	total: 20.4s	remaining: 11.6s
# 637:	learn: 0.5344220	total: 20.5s	remaining: 11.6s
# 638:	learn: 0.5343881	total: 20.5s	remaining: 11.6s
# 639:	learn: 0.5343427	total: 20.5s	remaining: 11.5s
# 640:	learn: 0.5343019	total: 20.6s	remaining: 11.5s
# 641:	learn: 0.5342689	total: 20.6s	remaining: 11.5s
# 642:	learn: 0.5342126	total: 20.6s	remaining: 11.4s
# 643:	learn: 0.5341579	total: 20.7s	remaining: 11.4s
# 644:	learn: 0.5340933	total: 20.7s	remaining: 11.4s
# 645:	learn: 0.5340439	total: 20.7s	remaining: 11.4s
# 646:	learn: 0.5339775	total: 20.8s	remaining: 11.3s
# 647:	learn: 0.5339325	total: 20.8s	remaining: 11.3s
# 648:	learn: 0.5338717	total: 20.8s	remaining: 11.3s
# 649:	learn: 0.5338323	total: 20.9s	remaining: 11.2s
# 650:	learn: 0.5337895	total: 20.9s	remaining: 11.2s
# 651:	learn: 0.5337539	total: 20.9s	remaining: 11.2s
# 652:	learn: 0.5337094	total: 21s	remaining: 11.1s
# 653:	learn: 0.5336705	total: 21s	remaining: 11.1s
# 654:	learn: 0.5336336	total: 21s	remaining: 11.1s
# 655:	learn: 0.5335755	total: 21s	remaining: 11s
# 656:	learn: 0.5335377	total: 21.1s	remaining: 11s
# 657:	learn: 0.5334954	total: 21.1s	remaining: 11s
# 658:	learn: 0.5334313	total: 21.1s	remaining: 10.9s
# 659:	learn: 0.5333802	total: 21.2s	remaining: 10.9s
# 660:	learn: 0.5333299	total: 21.2s	remaining: 10.9s
# 661:	learn: 0.5332828	total: 21.2s	remaining: 10.8s
# 662:	learn: 0.5332309	total: 21.3s	remaining: 10.8s
# 663:	learn: 0.5331806	total: 21.3s	remaining: 10.8s
# 664:	learn: 0.5331240	total: 21.3s	remaining: 10.7s
# 665:	learn: 0.5330600	total: 21.4s	remaining: 10.7s
# 666:	learn: 0.5330211	total: 21.4s	remaining: 10.7s
# 667:	learn: 0.5329754	total: 21.4s	remaining: 10.6s
# 668:	learn: 0.5329105	total: 21.4s	remaining: 10.6s
# 669:	learn: 0.5328681	total: 21.5s	remaining: 10.6s
# 670:	learn: 0.5328104	total: 21.5s	remaining: 10.5s
# 671:	learn: 0.5327591	total: 21.5s	remaining: 10.5s
# 672:	learn: 0.5327142	total: 21.6s	remaining: 10.5s
# 673:	learn: 0.5326555	total: 21.6s	remaining: 10.4s
# 907:	learn: 0.5219210	total: 29.1s	remaining: 2.95s
# 908:	learn: 0.5218882	total: 29.1s	remaining: 2.91s
# 909:	learn: 0.5218422	total: 29.1s	remaining: 2.88s
# 910:	learn: 0.5218184	total: 29.2s	remaining: 2.85s
# 911:	learn: 0.5217715	total: 29.2s	remaining: 2.82s
# 912:	learn: 0.5217256	total: 29.3s	remaining: 2.79s
# 913:	learn: 0.5216896	total: 29.3s	remaining: 2.75s
# 914:	learn: 0.5216321	total: 29.3s	remaining: 2.72s
# 915:	learn: 0.5215976	total: 29.4s	remaining: 2.69s
# 916:	learn: 0.5215416	total: 29.4s	remaining: 2.66s
# 917:	learn: 0.5214864	total: 29.4s	remaining: 2.63s
# 918:	learn: 0.5214453	total: 29.4s	remaining: 2.6s
# 919:	learn: 0.5214026	total: 29.5s	remaining: 2.56s
# 920:	learn: 0.5213563	total: 29.5s	remaining: 2.53s
# 921:	learn: 0.5213151	total: 29.5s	remaining: 2.5s
# 922:	learn: 0.5212695	total: 29.6s	remaining: 2.47s
# 923:	learn: 0.5212346	total: 29.6s	remaining: 2.44s
# 924:	learn: 0.5211901	total: 29.6s	remaining: 2.4s
# 925:	learn: 0.5211335	total: 29.7s	remaining: 2.37s
# 926:	learn: 0.5210912	total: 29.7s	remaining: 2.34s
# 927:	learn: 0.5210698	total: 29.7s	remaining: 2.31s
# 928:	learn: 0.5210288	total: 29.8s	remaining: 2.27s
# 929:	learn: 0.5209859	total: 29.8s	remaining: 2.24s
# 930:	learn: 0.5209635	total: 29.8s	remaining: 2.21s
# 931:	learn: 0.5209232	total: 29.9s	remaining: 2.18s
# 932:	learn: 0.5208688	total: 29.9s	remaining: 2.15s
# 933:	learn: 0.5208184	total: 29.9s	remaining: 2.12s
# 934:	learn: 0.5207832	total: 30s	remaining: 2.08s
# 935:	learn: 0.5207448	total: 30s	remaining: 2.05s
# 936:	learn: 0.5206971	total: 30s	remaining: 2.02s
# 937:	learn: 0.5206606	total: 30.1s	remaining: 1.99s
# 938:	learn: 0.5206054	total: 30.1s	remaining: 1.95s
# 939:	learn: 0.5205645	total: 30.1s	remaining: 1.92s
# 940:	learn: 0.5205315	total: 30.2s	remaining: 1.89s
# 941:	learn: 0.5204974	total: 30.2s	remaining: 1.86s
# 942:	learn: 0.5204525	total: 30.2s	remaining: 1.83s
# 943:	learn: 0.5204138	total: 30.2s	remaining: 1.79s
# 944:	learn: 0.5203601	total: 30.3s	remaining: 1.76s
# 945:	learn: 0.5203136	total: 30.3s	remaining: 1.73s
# 946:	learn: 0.5203055	total: 30.3s	remaining: 1.7s
# 947:	learn: 0.5202727	total: 30.4s	remaining: 1.66s
# 948:	learn: 0.5202330	total: 30.4s	remaining: 1.63s
# 949:	learn: 0.5201805	total: 30.4s	remaining: 1.6s
# 950:	learn: 0.5201539	total: 30.4s	remaining: 1.57s
# 951:	learn: 0.5201106	total: 30.5s	remaining: 1.54s
# 952:	learn: 0.5200578	total: 30.5s	remaining: 1.5s
# Out:
# ['yardline_100',
#  'game_seconds_remaining',
#  'qtr',
#  'down',
#  'ydstogo',
#  'ydsnet',
#  'yards_gained',
#  'shotgun',
#  'qb_dropback',
#  'score_differential',
#  'ep',
#  'epa',
#  'pts_scored_vs_pace',
#  'def_team_pts_scored_vs_pace',
#  'adj_wp',
#  'play_end_total_ydstogo',
#  'pd_run_percentage']

# %% [markdown]
# # Summary Results

# %%
pd.set_option('display.max_rows', None)
# put all selections together
feature_selection_df = pd.DataFrame({'Feature': feature_name, 'Pearson Correlation':cor_support, 'F-Test':f_support, 
                                     'Chi-Squared' : chi_support, 'Mutual Information' : mutual_support, 
                                     'Variance Threshold': variance_selectors, 'LassoCV': embedded_lr_support,'RFE - GB': rfe_support, 
                                     'RandomForest': embedded_clf_support, 'CatBoost': embedded_cbr_support, 
                                     'LightGBM' : embedded_lgb_support})

# Count the selected times for each feature
feature_selection_df['Total'] = np.sum(feature_selection_df, axis = 1)

# Display the top 100
feature_selection_df = feature_selection_df.sort_values(['Total', 'Feature'] , ascending = False)
feature_selection_df.index = range(1, len(feature_selection_df) + 1)
feature_selection_df.head(100)
# Out:
#                              Feature  Pearson Correlation  F-Test  \
# 1                            ydstogo                 True    True
# 2                       yards_gained                 True    True
# 3                 score_differential                 True    True
# 4                 pts_scored_vs_pace                 True    True
# 5                  pd_run_percentage                 True    True
# 6             game_seconds_remaining                 True    True
# 7                                epa                 True    True
# 8                                 ep                 True    True
# 9                               down                 True    True
# 10                            adj_wp                 True    True
# 11                            ydsnet                 True    True
# 12                           shotgun                 True    True
# 13            play_end_total_ydstogo                 True    True
# 14                  pd_passer_rating                 True    True
# 15       def_team_pts_scored_vs_pace                 True    True
# 16                            off_qb                 True    True
# 17                            off_lt                 True    True
# 18                       qb_dropback                False   False
# 19       play_end_first_down_ydstogo                 True    True
# 20            pd_pass_completion_pct                 True    True
# 21                       pd_expl_run                 True    True
# 22                 pd_average_points                 True    True
# 23                            off_wr                 True    True
# 24                         no_huddle                 True    True
# 25                ld_start_yds_to_go                 True    True
# 26                         game_half                 True    True
# 27                      yardline_100                False   False
# 28                              sack                 True    True
# 29                     play_type_run                 True    True
# 30  ld_opp_outcome_turnover_on_downs                 True    True
# 31          ld_opp_outcome_touchdown                 True    True
# 32        ld_opp_outcome_fumble_lost                 True    True
# 33                       ld_expl_run                 True    True
# 34                         air_yards                 True    True
# 35                              Dome                 True    True
# 36                 yards_after_catch                 True    True
# 37                               qtr                False   False
# 38                          qb_spike                 True    True
# 39                play_type_qb_spike                 True    True
# 40                    play_type_pass                 True    True
# 41                  pd_rush_yard_att                False   False
# 42              pd_avg_interceptions                 True    True
# 43                    pd_average_top                False   False
# 44                  pd_average_sacks                 True    True
# 45                  pd_average_plays                 True    True
# 46                            off_hb                 True    True
# 47                             off_c                False   False
# 48      ld_outcome_turnover_on_downs                 True    True
# 49                   ld_outcome_punt                 True    True
# 50                  ld_outcome_no_ld                 True    True
# 51              ld_opp_outcome_no_ld                 True    True
# 52       ld_opp_outcome_interception                 True    True
# 53         ld_opp_outcome_field_goal                 True    True
# 54                          def_lolb                 True    True
# 55                       qb_scramble                 True    True
# 56                  pd_pass_yard_att                False   False
# 57                            off_rt                False   False
# 58                          ld_plays                 True    True
# 59                      ld_expl_pass                False   False
# 60                   ld_drive_length                False   False
# 61                           def_mlb                False   False
# 62                            def_dt                False   False
# 63                            def_cb                False   False
# 64                            off_te                False   False
# 65                            off_rg                False   False
# 66                            off_lg                False   False
# 67              ld_outcome_touchdown                False   False
# 68           ld_outcome_interception                False   False
# 69            ld_outcome_fumble_lost                False   False
# 70                              home                False   False
# 71                            fumble                False   False
# 72                            def_ss                False   False
# 73                          def_rolb                False   False
# 74                            def_re                False   False
# 75                            def_le                False   False
# 76                            def_fs                False   False
# 77                              Snow                False   False
# 78                              Rain                False   False
# 79                    pd_average_tfl                False   False
# 80             ld_outcome_field_goal                False   False
# 81               ld_opp_outcome_punt                False   False
# 82        ld_opp_outcome_end_of_half                False   False
# 83                              Wind                False   False
# 84                         GameMonth                False   False
# 85                play_type_qb_kneel                False   False
# 86              play_type_field_goal                False   False
# 87                      pd_expl_pass                False   False
# 88            ld_outcome_end_of_half                False   False
# 89                               Fog                False   False
# 90                    play_type_punt                False   False
#
#     Chi-Squared  Mutual Information  Variance Threshold  LassoCV  RFE - GB  \
# 1          True                True                True     True      True
# 2          True                True                True     True      True
# 3          True                True                True     True      True
# 4          True                True                True     True      True
# 5          True                True                True     True      True
# 6          True                True                True     True      True
# 7          True                True                True     True      True
# 8          True                True                True     True      True
# 9          True                True                True     True      True
# 10         True                True                True     True      True
# 11         True                True                True    False      True
# 12         True                True                True     True      True
# 13         True               False                True     True      True
# 14         True                True                True     True      True
# 15         True                True                True    False      True
# 16         True               False                True     True      True
# 17         True               False                True     True      True
# 18         True                True                True     True      True
# 19         True               False                True    False      True
# 20         True               False                True     True      True
# 21         True                True                True     True      True
# 22         True                True                True     True      True
# 23        False               False                True     True      True
# 24         True                True                True     True      True
# 25         True               False                True     True      True
# 26         True                True                True     True      True
# 27        False               False                True     True      True
# 28         True                True                True     True     False
# 29         True                True                True    False      True
# 30         True                True                True     True     False
# 31         True                True                True     True     False
# 32         True                True                True     True     False
# 33         True                True                True     True     False
# 34        False               False                True     True      True
# 35         True                True                True     True     False
# 36        False                True                True     True     False
# 37        False                True                True     True      True
# 38         True               False                True     True     False
# 39         True               False                True     True     False
# 40         True                True                True    False     False
# 41        False                True                True    False      True
# 42         True                True                True    False     False
# 43        False                True                True     True      True
# 44         True                True                True    False     False
# 45        False               False                True    False      True
# 46        False               False                True    False      True
# 47        False               False                True     True      True
# 48         True               False                True     True     False
# 49         True                True                True    False     False
# 50         True                True                True    False     False
# 51         True                True                True    False     False
# 52         True               False                True     True     False
# 53         True                True                True    False     False
# 54        False               False                True    False      True
# 55         True               False                True    False     False
# 56        False                True                True    False      True
# 57        False               False                True     True      True
# 58        False               False                True     True     False
# 59         True                True                True     True     False
# 60        False               False                True     True      True
# 61        False               False                True     True      True
# 62        False               False                True     True      True
# 63        False               False                True     True      True
# 64        False               False                True    False      True
# 65        False               False                True    False      True
# 66        False               False                True    False      True
# 67         True                True                True    False     False
# 68         True                True                True    False     False
# 69         True                True                True    False     False
# 70        False                True                True     True     False
# 71         True               False                True     True     False
# 72        False               False                True    False      True
# 73        False               False                True    False      True
# 74        False               False                True    False      True
# 75        False               False                True    False      True
# 76        False               False                True    False      True
# 77         True               False                True     True     False
# 78        False                True                True     True     False
# 79        False                True                True    False     False
# 80        False                True                True    False     False
# 81        False                True                True    False     False
# 82        False                True                True    False     False
# 83        False                True                True    False     False
# 84        False                True                True    False     False
# 85        False               False                True    False     False
# 86        False               False                True    False     False
# 87        False               False                True    False     False
# 88        False               False                True    False     False
# 89        False               False                True    False     False
# 90        False               False               False    False     False
#
#     RandomForest  CatBoost  LightGBM  Total
# 1           True      True      True     10
# 2           True      True      True     10
# 3           True      True      True     10
# 4           True      True      True     10
# 5           True      True      True     10
# 6           True      True      True     10
# 7           True      True      True     10
# 8           True      True      True     10
# 9           True      True      True     10
# 10          True      True      True     10
# 11          True      True      True      9
# 12         False      True      True      9
# 13          True      True      True      9
# 14          True     False      True      9
# 15          True      True      True      9
# 16          True     False      True      8
# 17          True     False      True      8
# 18         False      True      True      7
# 19          True     False      True      7
# 20          True     False     False      7
# 21         False     False     False      7
# 22         False     False     False      7
# 23          True     False      True      7
# 24         False     False     False      7
# 25          True     False     False      7
# 26         False     False     False      7
# 27          True      True      True      6
# 28         False     False     False      6
# 29         False     False     False      6
# 30         False     False     False      6
# 31         False     False     False      6
# 32         False     False     False      6
# 33         False     False     False      6
# 34          True     False     False      6
# 35         False     False     False      6
# 36         False     False     False      5
# 37         False      True     False      5
# 38         False     False     False      5
# 39         False     False     False      5
# 40         False     False     False      5
# 41          True     False      True      5
# 42         False     False     False      5
# 43          True     False     False      5
# 44         False     False     False      5
# 45          True     False     False      5
# 46          True     False     False      5
# 47          True     False      True      5
# 48         False     False     False      5
# 49         False     False     False      5
# 50         False     False     False      5
# 51         False     False     False      5
# 52         False     False     False      5
# 53         False     False     False      5
# 54          True     False     False      5
# 55         False     False     False      4
# 56          True     False     False      4
# 57          True     False     False      4
# 58         False     False     False      4
# 59         False     False     False      4
# 60          True     False     False      4
# 61          True     False     False      4
# 62          True     False     False      4
# 63          True     False     False      4
# 64          True     False     False      3
# 65          True     False     False      3
# 66          True     False     False      3
# 67         False     False     False      3
# 68         False     False     False      3
# 69         False     False     False      3
# 70         False     False     False      3
# 71         False     False     False      3
# 72          True     False     False      3
# 73          True     False     False      3
# 74          True     False     False      3
# 75          True     False     False      3
# 76          True     False     False      3
# 77         False     False     False      3
# 78         False     False     False      3
# 79         False     False     False      2
# 80         False     False     False      2
# 81         False     False     False      2
# 82         False     False     False      2
# 83         False     False     False      2
# 84         False     False     False      2
# 85         False     False     False      1
# 86         False     False     False      1
# 87         False     False     False      1
# 88         False     False     False      1
# 89         False     False     False      1
# 90         False     False     False      0
